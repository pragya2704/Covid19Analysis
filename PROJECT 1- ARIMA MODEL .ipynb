# %%
#importing the libraries 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#ATTACHING THE LIVE DATA
confirmed_cases_file_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
death_cases_file_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
recovered_cases_file_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"
country_cases_file_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv"

# %%
#READING THE COMMA SEPARATED VALUES FILES AND GETTING ITS SHAPE
confirmed_df = pd.read_csv(confirmed_cases_file_link,index_col=[1])
print(confirmed_df.shape)
deaths_df = pd.read_csv(death_cases_file_link,index_col=[1])
print(deaths_df.shape)
recovered_df = pd.read_csv(recovered_cases_file_link,index_col=[1])
print(recovered_df.shape)
cases_country_df = pd.read_csv(country_cases_file_link,index_col=[1])
print(cases_country_df.shape)
# Out:
# (266, 194)
# (266, 194)
# (253, 194)
# (188, 13)

# %%
confirmed_df
# Out:
#                       Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# Afghanistan                      NaN  33.000000  65.000000        0        0
# Albania                          NaN  41.153300  20.168300        0        0
# Algeria                          NaN  28.033900   1.659600        0        0
# Andorra                          NaN  42.506300   1.521800        0        0
# Angola                           NaN -11.202700  17.873900        0        0
# ...                              ...        ...        ...      ...      ...
# Sao Tome and Principe            NaN   0.186360   6.613081        0        0
# Yemen                            NaN  15.552727  48.516388        0        0
# Comoros                          NaN -11.645500  43.333300        0        0
# Tajikistan                       NaN  38.861034  71.276093        0        0
# Lesotho                          NaN -29.609988  28.233608        0        0
#
# ...

# %%
del confirmed_df['Lat']

# %%
del confirmed_df['Long']

# %%
del confirmed_df['Province/State']

# %%
confirmed_df
# Out:
#                        1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                  0        0        0        0        0        0
# Albania                      0        0        0        0        0        0
# Algeria                      0        0        0        0        0        0
# Andorra                      0        0        0        0        0        0
# Angola                       0        0        0        0        0        0
# ...                        ...      ...      ...      ...      ...      ...
# Sao Tome and Principe        0        0        0        0        0        0
# Yemen                        0        0        0        0        0        0
# Comoros                      0        0        0        0        0        0
# Tajikistan                   0        0        0        0        0        0
# Lesotho                      0        0        0        0        0        0
#
# ...

# %%
confirmed_df.describe()
# Out:
#           1/22/20     1/23/20     1/24/20     1/25/20      1/26/20  \
# count  266.000000  266.000000  266.000000  266.000000   266.000000
# mean     2.086466    2.458647    3.537594    5.390977     7.962406
# std     27.279200   27.377862   34.083035   47.434934    66.289178
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    0.000000    0.000000    0.000000     0.000000
# 50%      0.000000    0.000000    0.000000    0.000000     0.000000
# 75%      0.000000    0.000000    0.000000    0.000000     0.000000
# max    444.000000  444.000000  549.000000  761.000000  1058.000000
#
#            1/27/20      1/28/20      1/29/20      1/30/20      1/31/20  ...  \
# count   266.000000   266.000000   266.000000   266.000000   266.000000  ...
# mean     11.003759    20.969925    23.180451    30.954887    37.319549  ...
# std      89.313757   219.187744   220.524977   303.897894   360.297287  ...
# ...

# %%
del deaths_df['Lat']

# %%
del deaths_df['Long']

# %%
del deaths_df['Province/State']

# %%
deaths_df
# Out:
#                        1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                  0        0        0        0        0        0
# Albania                      0        0        0        0        0        0
# Algeria                      0        0        0        0        0        0
# Andorra                      0        0        0        0        0        0
# Angola                       0        0        0        0        0        0
# ...                        ...      ...      ...      ...      ...      ...
# Sao Tome and Principe        0        0        0        0        0        0
# Yemen                        0        0        0        0        0        0
# Comoros                      0        0        0        0        0        0
# Tajikistan                   0        0        0        0        0        0
# Lesotho                      0        0        0        0        0        0
#
# ...

# %%
deaths_df.describe()
# Out:
#           1/22/20     1/23/20     1/24/20     1/25/20     1/26/20     1/27/20  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean     0.063910    0.067669    0.097744    0.157895    0.210526    0.308271
# std      1.042337    1.043908    1.473615    2.453621    3.189730    4.660845
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max     17.000000   17.000000   24.000000   40.000000   52.000000   76.000000
#
#           1/28/20     1/29/20     1/30/20     1/31/20  ...        6/28/20  \
# count  266.000000  266.000000  266.000000  266.000000  ...     266.000000
# mean     0.492481    0.500000    0.642857    0.800752  ...    1888.909774
# ...

# %%
del recovered_df['Lat']

# %%
del recovered_df['Long']

# %%
del recovered_df['Province/State']

# %%
recovered_df
# Out:
#                        1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                  0        0        0        0        0        0
# Albania                      0        0        0        0        0        0
# Algeria                      0        0        0        0        0        0
# Andorra                      0        0        0        0        0        0
# Angola                       0        0        0        0        0        0
# ...                        ...      ...      ...      ...      ...      ...
# Sao Tome and Principe        0        0        0        0        0        0
# Yemen                        0        0        0        0        0        0
# Comoros                      0        0        0        0        0        0
# Tajikistan                   0        0        0        0        0        0
# Lesotho                      0        0        0        0        0        0
#
# ...

# %%
recovered_df.describe()
# Out:
#           1/22/20     1/23/20     1/24/20     1/25/20     1/26/20     1/27/20  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000  253.000000
# mean     0.110672    0.118577    0.142292    0.154150    0.205534    0.241107
# std      1.760345    1.764332    1.954723    2.020714    2.649732    2.852382
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max     28.000000   28.000000   31.000000   32.000000   42.000000   45.000000
#
#           1/28/20     1/29/20     1/30/20     1/31/20  ...        6/28/20  \
# count  253.000000  253.000000  253.000000  253.000000  ...     253.000000
# mean     0.422925    0.498024    0.565217    0.877470  ...   20319.758893
# ...

# %%
position = confirmed_df.index.get_loc("India")

# %%
confirmed_df.iloc[position]
# Out:
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
#             ...
# 7/3/20     648315
# 7/4/20     673165
# 7/5/20     697413
# 7/6/20     719664
# 7/7/20     742417
# Name: India, Length: 168, dtype: int64

# %%
confirmed_india = confirmed_df.iloc[confirmed_df.index.get_loc('India')]

# %%
confirmed_india
# Out:
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
#             ...
# 7/3/20     648315
# 7/4/20     673165
# 7/5/20     697413
# 7/6/20     719664
# 7/7/20     742417
# Name: India, Length: 168, dtype: int64

# %%
deaths_india = deaths_df.iloc[deaths_df.index.get_loc('India')]

# %%
deaths_india
# Out:
# 1/22/20        0
# 1/23/20        0
# 1/24/20        0
# 1/25/20        0
# 1/26/20        0
#            ...
# 7/3/20     18655
# 7/4/20     19268
# 7/5/20     19693
# 7/6/20     20159
# 7/7/20     20642
# Name: India, Length: 168, dtype: int64

# %%
recovered_india = recovered_df.iloc[recovered_df.index.get_loc('India')]

# %%
recovered_india
# Out:
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
#             ...
# 7/3/20     394227
# 7/4/20     409083
# 7/5/20     424433
# 7/6/20     439934
# 7/7/20     456831
# Name: India, Length: 168, dtype: int64

# %%
axis = confirmed_india.plot(legend=True, label='confirmed')
axis = recovered_india.plot(ax=axis, legend=True, label='recovered')
deaths_india.plot(ax=axis, legend=True, label='deaths')

# %% [markdown]
# ARIMA MODEL

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(confirmed_india)

# %%
plot_pacf(confirmed_india)

# %%
from statsmodels.tsa.arima_model import ARIMA
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
confirmed_india_stable = np.sqrt(confirmed_india)

# %%
confirmed_model = ARIMA(confirmed_india_stable,order=(12,2,2))
# Out:
# C:\Users\Pragya Shahi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\Pragya Shahi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
confirmed_model_fit = confirmed_model.fit()

# %%
confirmed_model_fit.aic
# Out:
# 499.24842297424675

# %%
confirmed_model_fit.forecast(steps=36)[0]
# Out:
# array([ 875.76989394,  890.52798486,  905.37557415,  919.84053517,
#         934.10396175,  948.29855307,  962.71172628,  977.37107107,
#         992.32130289, 1007.51431009, 1022.48750482, 1037.34184557,
#        1052.28487197, 1067.52201944, 1083.01279443, 1098.56234864,
#        1114.090799  , 1129.61070594, 1145.20024943, 1160.93592753,
#        1176.78196287, 1192.78770672, 1208.8518824 , 1224.94199008,
#        1241.0712625 , 1257.29057007, 1273.65997969, 1290.14174645,
#        1306.70719237, 1323.32350261, 1340.00246788, 1356.77477358,
#        1373.64477007, 1390.61785146, 1407.68785455, 1424.82988207])

# %% [markdown]
# Death Cases

# %%
deaths_india = deaths_df.iloc[deaths_df.index.get_loc('India')]

# %%
deaths_india
# Out:
# 1/22/20        0
# 1/23/20        0
# 1/24/20        0
# 1/25/20        0
# 1/26/20        0
#            ...
# 7/3/20     18655
# 7/4/20     19268
# 7/5/20     19693
# 7/6/20     20159
# 7/7/20     20642
# Name: India, Length: 168, dtype: int64

# %%
plot_acf(deaths_india)

# %%
plot_pacf(deaths_india)

# %%
deaths_india_stable = np.sqrt(deaths_india)

# %%
deaths_model = ARIMA(deaths_india_stable,order=(12,2,2))
# Out:
# C:\Users\Pragya Shahi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\Pragya Shahi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
deaths_model_fit = deaths_model.fit()

# %%
deaths_model_fit.aic
# Out:
# 376.65231215282694

# %%
deaths_model_fit.forecast(steps=36)[0]
# Out:
# array([145.66554473, 147.66403193, 149.66923381, 151.69891693,
#        153.75995024, 155.82224937, 157.95465209, 160.08482854,
#        162.25939235, 164.41209366, 166.61502732, 168.81082548,
#        171.05038848, 173.28056988, 175.54904468, 177.81080459,
#        180.1078761 , 182.40133095, 184.72800513, 187.05215422,
#        189.40681582, 191.76070507, 194.14367321, 196.5274296 ,
#        198.93854827, 201.35178678, 203.79093272, 206.23347922,
#        208.70069669, 211.17248172, 213.66779766, 216.16868872,
#        218.69211227, 221.22204216, 223.77362139, 226.33253083])

# %% [markdown]
# Recovered cases

# %%
recovered_india = recovered_df.iloc[recovered_df.index.get_loc('India')]

# %%
recovered_india
# Out:
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
#             ...
# 7/3/20     394227
# 7/4/20     409083
# 7/5/20     424433
# 7/6/20     439934
# 7/7/20     456831
# Name: India, Length: 168, dtype: int64

# %%
plot_acf(recovered_india)

# %%
plot_pacf(recovered_india)

# %%
recovered_india_stable = np.sqrt(recovered_india)

# %%
recovered_model = ARIMA(recovered_india_stable,order=(12,2,2))
# Out:
# C:\Users\Pragya Shahi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\Pragya Shahi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
recovered_model_fit = recovered_model.fit()

# %%
recovered_model_fit.aic
# Out:
# 648.2967531844354

# %%
recovered_model_fit.forecast(steps=36)[0]
# Out:
# array([ 688.96324602,  700.93918823,  713.7101667 ,  726.72551001,
#         739.41149105,  751.75898525,  763.26171961,  778.27311632,
#         791.53702628,  804.19491139,  817.22353114,  830.42135379,
#         844.02774629,  857.44528906,  870.81329419,  884.36020383,
#         898.46214175,  912.3485273 ,  925.86519422,  938.89070848,
#         953.73165596,  968.19745325,  981.94257152,  995.97963687,
#        1010.32293697, 1024.95350811, 1039.2293275 , 1053.61969874,
#        1068.1500609 , 1083.10761655, 1098.03982087, 1112.67569354,
#        1127.06512222, 1142.38283016, 1157.81609463, 1172.69203863])
